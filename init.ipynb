# %%
import pandas as pd
import os
ruta = os.getcwd()
pathx=(f"{ruta}/datos.xlsx")
path=(f"{ruta}/datos.json")

dfx = pd.read_excel(pathx)
# nota instalar pip install openpyxl
#nota 2

df = pd.read_json(path)


result = pd.concat([df,dfx], ignore_index=True,axis=0)

result
# Out:
#    N_IDENTIFICACION NOMBRE_ANIMAL NOMBRE_CIENTIFICO ESTATUS_CONSERVACION  \
# 0              1456          LEON      PANTHERA LEO                    V
# 1              1457         TIGRE   PANTHERA TIGRIS                    V
# 2              1458       CHEETAH  ACINONYX JUBATUS                    V
# 3              1459           NaN               NaN                  NaN
# 4              1460           NaN               NaN                  NaN
# 5              1461           NaN               NaN                  NaN
#
#   SEXO_ANIMAL  ANIO_NACIMIENTO PESO_ANIMAL  ALTURA_ANIMAL  ID_FAMILIA  \
# 0           M           2015.0                      130.0         1.0
# 1           F           2016.0          98          120.0         1.0
# 2           M           2017.0                       75.0         1.0
# 3         NaN              NaN         NaN            NaN         NaN
# 4         NaN              NaN         NaN            NaN         NaN
# ...
